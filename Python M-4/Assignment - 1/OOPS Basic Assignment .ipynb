# %%
#1. Create a Vehicle class without any variables and methods
class Vehicle:
  pass

# %%
#2. Create a child class Bus that will inherit all of the variables and methods of the Vehicle class
class Bus(Vehicle):
  pass

# %%
# 3. Write a Program to create a class by name Students, and initialize attributes like name, age, and grade while creating an object.
class Students:
  def __init__(self,name,age,*grade):
    self.name=name
    self.age=age;
    self.grade=grade
s=Students("Abhishek",22,50,60,70,80)

# %%
# 4. Write a Program to create a valid empty class by name Students, with no properties
class Students:
  pass

# %%
# 5. Write a program to create a child class Teacher that will inherit the properties of Parent class Staff
class Staff:
  pass
class Teacher(Staff):
  pass

# %%
# 6. Write a Python program that checks if one class is a subclass of another.

# %%
# 7. Write a Program to create a class and, using the class instance, print all the writable attributes of that object.

class Automobile:
  def __init__(self,make,model,year) :
    self.make=make
    self.model=model
    self.year=year
  def display(self):
    return f"The brand {self.make} built the car {self.model} in the year {self.year}."

car1=Automobile("Audi","Audi A4",2021)
car1.display()
# Out:
# 'The brand Audi built the car Audi A4 in the year 2021.'

# %%
# 8. Create a class Teacher with name, age, and salary attributes, where salary must be a private attribute that cannot be accessed outside the class.
class Teacher:
  def __init__(self,name,age,salary):
    self.__name=name
    self.__age=age
    self.__salary=salary

T1=Teacher("Abhishek",22,95000)

# %%
# 9. Write a Python program to create an instance of a specified class and display the namespace of the said instance
class Cars:
  def __init__(self):
    make=input("Enter the Make of the car: ")
    self.make=make
    model=input("Enter the model of the car: ")
    self.model=model
    print(f"{make} Makes {model} which has high popularity ")

car1=Cars()
# Out:
# Enter the Make of the car: BMW
# Enter the model of the car: M4
# BMW Makes M4 which has high popularity

# %%
# 10. Define a Python function student(). Using function attributes display the names of all arguments

class students:
  def __init__(self,name):
    self.name=name
  def __str__(self):
    return name

name=input("Enter the Name: ")
print(students(name))
students.gender="Male"
print(students.gender)
students.age=22
print(students.age)
# Out:
# Enter the Name: Abhishek
# Abhishek
# Male
# 22

# %%
# 11. Write a Python function student_data () which will print the id of a student (student_id). If the user passes an argument student_name or student_class the function will print the student name and class.
class Student:
  def __init__(self,student_id,student_name=None,student_class=None):
    self.student_id=student_id
    self.student_name=student_name
    self.student_class=student_class
  def display(self):
    if self.student_name and self.student_class:
      return f"ID: {self.student_id}, Name: {self.student_name}, Class: {self.student_class}"
    elif self.student_name:
      return f"ID: {self.student_id}, Name: {self.student_name}"
    else:
      return f"ID: {self.student_id}"
s1=Student(1,"Abhishek","A")
print(s1.display())
s2=Student(2,"Rohan")
print(s2.display())
s3=Student(3)
print(s3.display())
# Out:
# ID: 1, Name: Abhishek, Class: A
# ID: 2, Name: Rohan
# ID: 3

# %%
# 12. Write a simple Python class named Student and display its type. Also, display the __dict__ attribute keys and the value of the __module__ attribute of the Student class.
class Student:
    def __init__(self, name, age):
        self.name = name
        self.age = age
    def __str__(self):
        return 'name:',self.name + 'age:',self.age
    
print(type(Student))
print(Student.__dict__.keys())
print('='*20)
print(Student.__module__)
# Out:
# <class 'type'>
# dict_keys(['__module__', '__init__', '__str__', '__dict__', '__weakref__', '__doc__'])
# ====================
# __main__

# %%
# 13. Write a Python program to create two empty classes, Student and Marks. Now create some instances and check whether they are instances of the said classes or not. Also, check whether the said classes are subclasses of the built-in object class or not.
class Student:
    pass
class Marks:
    pass

s1=Student()
m1=Marks()
print(isinstance(s1,Student))
print(isinstance(m1,Marks))
print(issubclass(Student,object))
print(issubclass(Marks,object))
# Out:
# True
# True
# True
# True

# %%
# 14. Write a Python class named Student with two attributes: student_name, marks. Modify the attribute values of the said class and print the original and modified values of the said attributes.
class Student:
    def __init__(self,student_name,marks):
        self.student_name=student_name
        self.marks=marks
    def display(self):
        return f"Name: {self.student_name}, Marks: {self.marks}"
s1=Student("Abhishek",85)
print("Original:",s1.display())
s1.student_name="Rohan"
s1.marks=90
print("Modified:",s1.display())
# Out:
# Original: Name: Abhishek, Marks: 85
# Modified: Name: Rohan, Marks: 90

# %%
# 15.Write a Python class named Student with two attributes student_id, student_name. Add a new attribute student_class and display the entire attribute and their values of the said class. Now remove the student_name attribute and display the entire attribute with values
class Student:
    def __init__(self,student_id,student_name):
        self.student_id=student_id
        self.student_name=student_name
        self.student_class=None
    def display(self):
        return f"ID: {self.student_id}, Name: {self.student_name}, Class: {self.student_class}"
    def remove_name(self):
        del self.student_name
        return f"ID: {self.student_id}, Class: {self.student_class}"

s1=Student(1,"Abhishek")
s1.student_class="A"
print("With Name:",s1.display())
print("Without Name:",s1.remove_name())
print("Without Name:",s1.__dict__)
# Out:
# With Name: ID: 1, Name: Abhishek, Class: A
# Without Name: ID: 1, Class: A
# Without Name: {'student_id': 1, 'student_class': 'A'}

# %%
# 16.Write a Python class named Student with two attributes student_id, student_name. Add a new attribute student_class. Create a function to display the entire attribute and their values in Student class.
class Student:
    def __init__(self,student_id,student_name):
        self.student_id=student_id
        self.student_name=student_name
    def add_class(self,student_class):
        self.student_class=student_class

    def display(self):
        return f"ID: {self.student_id}, Name: {self.student_name}, Class: {self.student_class}"
    
s1=Student(1,"HappyNew")
s1.add_class("A")
print(s1.display())
# Out:
# ID: 1, Name: HappyNew, Class: A

# %%
# 17.Write a Python class named Student with two instances student1, student2 and assign given values to the said instances attributes. Print all the attributes of student1, student2 instances with their values in the given format
class Student:
    def __init__(self,student_id,student_name,student_class):
        self.student_id=student_id
        self.student_name=student_name
        self.student_class=student_class
    def display(self):
        return f"ID : {self.student_id}, Name: {self.student_name}, Class: {self.student_class}"

Student1=Student(1,"Abhishek","A")
Student2=Student(2,"Rohan","B")
print("Student 1 --> ",Student1.display())
print("Student 2 --> ",Student2.display())
# Out:
# Student 1 -->  ID : 1, Name: Abhishek, Class: A
# Student 2 -->  ID : 2, Name: Rohan, Class: B

# %%
# 18. Write a Python class to find the validity of a string of parentheses, '(', ')', '{', '}', '[' and ']. These brackets must be closed in the correct order, for example "()" and "()[]{}" are valid but "[)", "({[)]" and "{{{" are invalid.
class Parentheses:
    def __init__(self,parens):
        self.parens=parens
    def is_valid(self):
        stack=[]
        flag=True
        for char in self.parens: 
            if char in "({[":
                stack.append(char)
            elif char in ")}]":
                if len(stack)==0:
                    return False
                else:
                    if (char==')'and stack[-1]=='(') or (char=='}'and stack[-1]=='{') or (char==']'and stack[-1]=='['):
                        stack.pop()
                    
        if len(stack)==0:
            return True
        else:
            return False
        
s1=Parentheses("{[}]")
print(s1.is_valid())
# Out:
# False

# %%
# 19. Write a Python class to find a pair of elements (indices of the two numbers) from a given array whose sum equals a specific target number.
# Note: There will be one solution for each input and do not use the same element twice.
# Input: numbers= [10,20,10,40,50,60,70], target=50
# Output: 3, 4

class Pairsnum:
    def __init__(self,numbers,target):
        self.numbers=numbers
        self.target=target
    def find_pair(self):
        num_dict={}
        for num in enumerate(self.numbers):
            complement=self.target - num[1]
            if complement in num_dict:
                return (num_dict[complement],num[0])
            num_dict[num[1]]=num[0]
            
        return None

        # for i,num in enumerate(self.numbers):
        #     complement=self.target - num
        #     if complement in num_dict:
        #         return (num_dict[complement],i)
        #     num_dict[num]=i
        # return None

s1=Pairsnum([10,20,10,40,50,60,70],50)
print(s1.find_pair())
# Out:
# (2, 3)

# %%
# 20.Write a Python class to reverse a string word by word.
# Input string : 'hello .py'
# Expected Output : '.py hello'

class ReverseString:
    def __init__(self,string):
        self.string=string
    def reverse(self):
        word=list(self.string)
        for ch in range(len(word)-1,-1,-1):
            print(word[ch],end="")

s1=ReverseString("hellopy")
s1.reverse()
# Out:
# ypolleh

# %%
# 21.Write a Python class named Circle constructed by a radius and two methods which will compute the area and the perimeter of a circle

class Circle:
    def __init__(self,radius):
        self.radius=radius
    def area(self):
        return 3.14*self.radius*self.radius
    def perimeter(self):
        return 2*3.14*self.radius
c1=Circle(5)
print("Area:",c1.area())
# Out:
# Area: 78.5

# %%
# 22.Write a Python class which has two methods get_String and print_String. get_String accept a string from the user and print_String print the string in upper case.

class StringMethods:
    def __init__(self):
        self.string=""
    def get_String(self):
        self.string=input("Enter the String: ")
    def print_String(self):
        print(self.string.upper())

s1=StringMethods()
s1.get_String()
s1.print_String()
# Out:
# ABHISHEK

# %%
# 23.Write a Python class named Rectangle constructed by a length and width and a method which will compute the area of a rectangle
class Rectangle:
    def __init__(self,length,width):
        self.length=length
        self.width=width
    def area(self):
        return self.length*self.width
r1=Rectangle(5,10)
print("Area:",r1.area())
# Out:
# Area: 50

# %%
# 24.Create a class Shape that has a method area() and a method perimeter(). Create subclasses Rectangle and Circle that inherit from Shape and override the area() and perimeter() methods as appropriate.

class shape:
    def area(self):
        pass
    def perimeter(self):
        pass

class Rectangle(shape):
    def __init__(self,length,width):
        self.length=length
        self.width=width
    def area(self):
        return self.length*self.width
    def perimeter(self):
        return 2*(self.length+self.width)
class Circle(shape):
    def __init__(self,radius):
        self.radius=radius
    def area(self):
        return 3.14*self.radius*self.radius
    def perimeter(self):
        return 2*3.14*self.radius
r1=Rectangle(5,10)          
print("Rectangle Area:",r1.area())
print("Rectangle Perimeter:",r1.perimeter())
c1=Circle(7)
print("Circle Area:",c1.area())
print("Circle Perimeter:",c1.perimeter())
# Out:
# Rectangle Area: 50
# Rectangle Perimeter: 30
# Circle Area: 153.86
# Circle Perimeter: 43.96

# %%
# 25.Create a class Person that has properties name and age. Create a subclass Student that inherits from Person and adds a property major. Create a subclass Teacher that also inherits from Person and adds a property subject. Create instances of each class and print out their properties.

class Person:
    def __init__(self,name,age):
        self.name=name
        self.age=age
    def display(Self):
        return f"Name : {Self.name}, Age : {Self.age}"

class Student(Person):
    def __init__(self,name,age,major):
        super().__init__(name,age)
        self.major=major
    def display(Self):
        return f'Name : {Self.name}, Age : {Self.age}, Major : {Self.major}'

class Teacher(Person):
    def __init__(Self,name,age,Subject):
        super().__init__(name,age)
        Self.Subject=Subject
    def display(self):
        return f'Name : {self.name}, Age : {self.age}, Subject : {self.Subject}'
p1=Person("Abhishek",22)
print(p1.display())
s1=Student(p1.name,p1.age,"Computer Science")
print(s1.display())     
t1=Teacher("Mr. Sharma",45,"Mathematics")
print(t1.display())
# Out:
# Name : Abhishek, Age : 22
# Name : Abhishek, Age : 22, Major : Computer Science
# Name : Mr. Sharma, Age : 45, Subject : Mathematics

# %%
# 26.Create a class Vehicle that has properties make, model, and year. Create a subclass Car that inherits from Vehicle and adds a property num_doors. Create a subclass Motorcycle that also inherits from Vehicle and adds a property num_wheels. Create instances of each class and print out their properties.

class Vehicle:
    def __init__(self,make,model,year):
        self.make=make
        self.model=model
        self.year=year
    def display(self):
        return f"Make : {self.make}, Model : {self.model}, Year : {self.year}"
class Car(Vehicle):
    def __init__(self,make,model,year,num_doors):
        super().__init__(make,model,year)
        self.num_doors=num_doors
    def display(self):
        return f"Make : {self.make}, Model : {self.model}, Year : {self.year}, Number of Doors : {self.num_doors}"
class Motorcycle(Vehicle):
    def __init__(self,make,model,year,num_wheels):
        super().__init__(make,model,year)
        self.num_wheels=num_wheels
    def display(self):
        return f"Make : {self.make}, Model : {self.model}, Year : {self.year}, Number of Wheels : {self.num_wheels}"
v1=Vehicle("Toyota","Camry",2020)
print(v1.display()) 
c1=Car("Honda","Civic",2021,4)
print(c1.display())
m1=Motorcycle("Yamaha","YZF-R3",2022,2)
print(m1.display())
# Out:
# Make : Toyota, Model : Camry, Year : 2020
# Make : Honda, Model : Civic, Year : 2021, Number of Doors : 4
# Make : Yamaha, Model : YZF-R3, Year : 2022, Number of Wheels : 2

# %%
# 27.Create a class Animal that has a method speak() that prints out the sound the animal makes. Create subclasses Dog, Cat, and Cow that inherit from Animal and override the speak() method to print out the appropriate sound for each animal. Create instances of each subclass and call their speak() methods.
class Animal:
    def speak(self):
        pass
class Dog(Animal):
    def speak(self):
        return "Woof Woof"
class Cat(Animal):
    def speak(self):
        return "Meow Meow"
class Cow(Animal):
    def speak(self):
        return "Moo Moo"
d1=Dog()
print("Dog:",d1.speak())
c1=Cat()
print("Cat:",c1.speak())
cw1=Cow()
print("Cow:",cw1.speak())
# Out:
# Dog: Woof Woof
# Cat: Meow Meow
# Cow: Moo Moo

# %%
# 28.Create a class BankAccount that has properties balance and interest_rate. Create a subclass CheckingAccount that inherits from BankAccount and adds a property transaction_fee. Create a subclass SavingsAccount that also inherits from BankAccount and adds a property min_balance. Create instances of each class and print out their properties. Then call a method on each instance that adds interest to the account.

class BankAccount:
    def __init__(self,balance,interest_rate):
        self.balance=balance
        self.interest_rate=interest_rate
    def add_interest(self):
        self.balance += self.balance * self.interest_rate / 100
        return self.balance

class CheckingAccount(BankAccount):
    def __init__(self,balance,intereset_rate,transaction_fee):
        super().__init__(balance,intereset_rate)
        self.transaction_fee=transaction_fee
    def add_interest(self):
        self.balance-=self.transaction_fee
        return super().add_interest()
class SavingsAccount(BankAccount):
    def __init__(self,balance,interest_rate,min_balance):
        super().__init__(balance,interest_rate)
        self.min_balance=min_balance
    def add_interest(self):
        if self.balance>=self.min_balance:
            return super().add_interest()
        else:
            return "Balance is less than Minimum Balance"
b1=BankAccount(1000,5)
print("Bank Account Balance after interest:",b1.add_interest())
c1=CheckingAccount(2000,4,10)
print("Checking Account Balance after interest:",c1.add_interest())
s1=SavingsAccount(1500,6,1000)
print("Savings Account Balance after interest:",s1.add_interest())
# Out:
# Bank Account Balance after interest: 1050.0
# Checking Account Balance after interest: 2069.6
# Savings Account Balance after interest: 1590.0

# %%
# 29.Create a class Animal that has a method speak() that prints out the sound the animal makes. Create subclasses Dog, Cat, and Cow that inherit from Animal and override the speak() method to print out the appropriate sound for each animal. Then create a list of Animal objects that includes instances of each subclass, and call the speak() method on each object.
class Animal:
    def speak(self):
        pass
class Dog(Animal):
    def speak(self):
        return "Woof Woof"
class Cat(Animal):
    def speak(self):
        return "Meow Meow"
class Cow(Animal):
    def speak(self):
        return "Moo Moo"
animals=[Dog(),Cat(),Cow()]
for animal in animals:
    print(animal.speak())
# Out:
# Woof Woof
# Meow Meow
# Moo Moo

# %%
# 30.Create a class Shape that has a method area() and a method perimeter(). Create subclasses Rectangle and Circle that inherit from Shape and override the area() and perimeter() methods as appropriate. Then create a list of Shape objects that includes instances of each subclass, and call the area() and perimeter() methods on each object.
class shape:
    def area(self):
        pass
    def perimeter(self):
        pass
class Rectangle(shape):
    def __init__(self,length,width):
        self.length=length
        self.width=width
    def area(self):
        return self.length*self.width
    def perimeter(self):
        return 2*(self.length+self.width)
class Circle(shape):
    def __init__(self,radius):
        self.radius=radius
    def area(self):
        return 3.14*self.radius*self.radius
    def perimeter(self):
        return 2*3.14*self.radius
shapes=[Rectangle(5,10),Circle(7)]
for shape in shapes:
    print("Area:",shape.area())
    print("Perimeter:",shape.perimeter())
# Out:
# Area: 50
# Perimeter: 30
# Area: 153.86
# Perimeter: 43.96

# %%
# 31.Create a class Person that has properties name and age. Create a subclass Student that inherits from Person and adds a property major. Create a subclass Teacher that also inherits from Person and adds a property subject. Create a list of Person objects that includes instances of each subclass, and print out their properties. Then call a method on each object that is specific to its subclass (e.g., a method that only exists on Student objects).
class Person:
    def __init__(self,name,age):
        self.name=name
        self.age=age
    def display(Self):
        return f"Name : {Self.name}, Age : {Self.age}"
class Student(Person):
    def __init__(self,name,age,major):
        super().__init__(name,age)
        self.major=major
    def display(Self):
        return f'Name : {Self.name}, Age : {Self.age}, Major : {Self.major}'
    def study(self):
        return f"{self.name} is studying {self.major}"
class Teacher(Person):
    def __init__(Self,name,age,Subject):
        super().__init__(name,age)
        Self.Subject=Subject
    def display(self):
        return f'Name : {self.name}, Age : {self.age}, Subject : {self.Subject}'
    def teach(self):
        return f"{self.name} is teaching {self.Subject}"
people=[Student("Abhishek",22,"Computer Science"),Teacher("Mr. Sharma",45,"Mathematics")]
for person in people:
    print(person.display())
    if isinstance(person,Student):
        print(person.study())
    elif isinstance(person,Teacher):
        print(person.teach())
# Out:
# Name : Abhishek, Age : 22, Major : Computer Science
# Abhishek is studying Computer Science
# Name : Mr. Sharma, Age : 45, Subject : Mathematics
# Mr. Sharma is teaching Mathematics

# %%
# 32.Create a class BankAccount that has properties balance and interest_rate. Create a subclass CheckingAccount that inherits from BankAccount and adds a property transaction_fee. Create a subclass SavingsAccount that also inherits from BankAccount and adds a property min_balance. Create a list of BankAccount objects that includes instances of each subclass, and print out their properties. Then call a method on each object that is specific to its subclass (e.g., a method that only exists on SavingsAccount objects).
class BankAccount:
    def __init__(self,balance,interest_rate):
        self.balance=balance
        self.interest_rate=interest_rate
    def add_interest(self):
        self.balance += self.balance * self.interest_rate / 100
        return self.balance
class CheckingAccount(BankAccount):
    def __init__(self,balance,intereset_rate,transaction_fee):
        super().__init__(balance,intereset_rate)
        self.transaction_fee=transaction_fee
    def add_interest(self):
        self.balance-=self.transaction_fee
        return super().add_interest()
class SavingsAccount(BankAccount):
    def __init__(self,balance,interest_rate,min_balance):
        super().__init__(balance,interest_rate)
        self.min_balance=min_balance
    def add_interest(self):
        if self.balance>=self.min_balance:
            return super().add_interest()
        else:
            return "Balance is less than Minimum Balance"
accounts=[BankAccount(1000,5),CheckingAccount(2000,4,10),SavingsAccount(1500,6,1000)]
for account in accounts:
    print("Balance:",account.balance)
    print("Interest Rate:",account.interest_rate)
    if isinstance(account,CheckingAccount):
        print("Transaction Fee:",account.transaction_fee)
        print("Balance after interest:",account.add_interest())
    elif isinstance(account,SavingsAccount):
        print("Minimum Balance:",account.min_balance)
        print("Balance after interest:",account.add_interest())
    else:
        print("Balance after interest:",account.add_interest())
    print("="*20)
# Out:
# Balance: 1000
# Interest Rate: 5
# Balance after interest: 1050.0
# ====================
# Balance: 2000
# Interest Rate: 4
# Transaction Fee: 10
# Balance after interest: 2069.6
# ====================
# Balance: 1500
# Interest Rate: 6
# Minimum Balance: 1000
# Balance after interest: 1590.0
# ====================

# %%
# 33.Create a class Vehicle that has properties make, model, and year. Create a subclass Car that inherits from Vehicle and adds a property num_doors. Create a subclass Motorcycle that also inherits from Vehicle and adds a property num_wheels. Create a list of Vehicle objects that includes instances of each subclass, and print out their properties. Then call a method on each object that is specific to its subclass (e.g., a method that only exists on Motorcycle objects)
class Vehicle:
    def __init__(self,make,model,year):
        self.make=make
        self.model=model
        self.year=year
    def display(self):
        return f"Make : {self.make}, Model : {self.model}, Year : {self.year}"
class Car(Vehicle):
    def __init__(self,make,model,year,num_doors):
        super().__init__(make,model,year)
        self.num_doors=num_doors
    def display(self):
        return f"Make : {self.make}, Model : {self.model}, Year : {self.year}, Number of Doors : {self.num_doors}"
   
class Motorcycle(Vehicle):
    def __init__(self,make,model,year,num_wheels):
        super().__init__(make,model,year)
        self.num_wheels=num_wheels
    def display(self):
        return f"Make : {self.make}, Model : {self.model}, Year : {self.year}, Number of Wheels : {self.num_wheels}"
    
vehicles=[Car("Honda","Civic",2021,4),Motorcycle("Yamaha","YZF-R3",2022,2)]
for vehicle in vehicles:
    print(vehicle.display())
    if isinstance(vehicle,Car):
        print(f"{vehicle.make} {vehicle.model} has {vehicle.num_doors} doors.")
    elif isinstance(vehicle,Motorcycle):
        print(f"{vehicle.make} {vehicle.model} has {vehicle.num_wheels} wheels.")
    print("="*20)
# Out:
# Make : Honda, Model : Civic, Year : 2021, Number of Doors : 4
# Honda Civic has 4 doors.
# ====================
# Make : Yamaha, Model : YZF-R3, Year : 2022, Number of Wheels : 2
# Yamaha YZF-R3 has 2 wheels.
# ====================
