# %% [markdown]
# 1. Create a string variable named my_string and assign it the value "qwertyuiopasdfghijkl asdfghjkzxcvbnm"

# %%
my_string="qwertyuiopasdfghijkl asdfghjkzxcvbnm"

# %% [markdown]
# 2. Print the thrid character of my_string using indexing.

# %%
my_string[2]
# Out:
# 'e'

# %% [markdown]
# 3.Print  the last Characters of my_String using indexing.

# %%
my_string[-1]
# Out:
# 'm'

# %% [markdown]
# 4. Print the first five characters of my_string using slicing

# %%
my_string[:5]
# Out:
# 'qwert'

# %% [markdown]
# 5. Print the last five Characters of my_string using slicing

# %%
my_string[:-6:-1]
# Out:
# 'mnbvc'

# %% [markdown]
# 6. Print every other characters of my_string using slicing

# %%
my_string[::2]
# Out:
# 'qetuoadgik sfhkxvn'

# %% [markdown]
# 7. Print my_string in reverse using slicing

# %%
my_string[::-1]
# Out:
# 'mnbvcxzkjhgfdsa lkjihgfdsapoiuytrewq'

# %% [markdown]
# 8. print the first two characters of my_string using slicing.

# %%
my_string[:2]
# Out:
# 'qw'

# %% [markdown]
# 9. Print the characters of my_string from index 7 to index 12 using slicing.

# %%
my_string[7:12]
# Out:
# 'iopas'

# %% [markdown]
# 10. Print the last three characters of my_string in reverse order using slicing.

# %%
my_string[:-4:-1]
# Out:
# 'mnb'

# %% [markdown]
# 11. Print the characters of my_string in reverse order using slicing.

# %%
my_string[::-1]
# Out:
# 'mnbvcxzkjhgfdsa lkjihgfdsapoiuytrewq'

# %% [markdown]
# 12. Print every thrid characters of my_string statring from the second characters

# %%
my_string[2::3]
# Out:
# 'eyosgj dhzvm'

# %% [markdown]
# 13.Create a new string variable named new_string and assign it the value "Learning is fun" Concatenate my_string and new_string using the + operator and print the resulting string.

# %%
new_string=" Learning is fun"
print(my_string+ new_string)
# Out:
# qwertyuiopasdfghijkl asdfghjkzxcvbnm Learning is fun

# %% [markdown]
# 14. Create a string variable name my_string and assign it the value "Python is easy to learn!"
#  * a. Print the length of my_string
#  * b. Convert my_string to uppercase and print it.
#  * c. Replace thee word " easy " in my_string with the word "Powerful" and Print the resulting string

# %%
my_strings="Python is easy to learn!"
a=len(my_strings)
print(a)

b=my_strings.upper()
print(b)

c=my_strings.replace('easy','Powerful')
print(c)
# Out:
# 24
# PYTHON IS EASY TO LEARN!
# Python is Powerful to learn!

# %% [markdown]
# 15.

# %%
email="jane.doe@example.com"

email[:8]
# Out:
# 'jane.doe'

# %%
email[:-12:-1]
# Out:
# 'moc.elpmaxe'

# %%
g= email.replace('example.com','Mycompany.com')
print(g)
# Out:
# jane.doe@Mycompany.com

# %% [markdown]
# 16.

# %%
my_string="Python is fun"

# %%
print('is' in my_string)
# Out:
# True

# %%
print('java' in my_string)
# Out:
# False

# %%
v=my_string.split()
print(v)
# Out:
# ['Python', 'is', 'fun']

# %% [markdown]
# 17.

# %%
my_string='Programming is fun!'

# %%
print("Programming is ")
# Out:
# Programming is

# %%
a=my_string.split()
print(a)
# Out:
# ['Programming', 'is', 'fun!']

# %%
" ".join(my_string)
# Out:
# 'P r o g r a m m i n g   i s   f u n !'

# %% [markdown]
# 18.

# %%
my_string="this is a test sentence"

# %%
my_string.count('e')
# Out:
# 4

# %%
my_string.find("test")
# Out:
# 10

# %%
my_string.replace("test","example")
# Out:
# 'this is a example sentence'

# %% [markdown]
# 19.

# %%
my_string="python"

# %%
my_string[2::-1]
# Out:
# 'typ'

# %%
my_string[-1:3:-1]
# Out:
# 'no'

# %%
"-".join(my_string)
# Out:
# 'p-y-t-h-o-n'

# %% [markdown]
# 20. Create a string variable named my_string and assign it the value "Pythonisa
# popular programming language".
# a. Use the title method to capitalize the first letter of each wordin
# my_string and print the resulting string.
# b. Use the split method to split my_string into a list of words andprint
# the result.
# c. Use the replace method to replace the word "Python" with "Java"in
# my_string and print the resulting string

# %%
my_string="Python is popular programming language"
my_string.title()
# Out:
# 'Python Is Popular Programming Language'

# %%
my_string.split()
# Out:
# ['Python', 'is', 'popular', 'programming', 'language']

# %%
my_string.replace("Python","Java")
# Out:
# 'Java is popular programming language'

# %% [markdown]
# 21.Create a string variable named my_string and assign it the value "Hello,
# World!".
# a. Use the lower method to convert my_string to lowercase andprint the
# resulting string.
# b. Use the upper method to convert my_string to uppercase andprint the
# resulting string.
# c. Use slicing to print the string "World" from my_string

# %%
my_string="Hello World"

print(my_string.lower())

print(my_string.upper())

print(my_string[6:])
# Out:
# hello world
# HELLO WORLD
# World

# %% [markdown]
# 22.Create a string variable named my_string and assign it the value "racecar". a. Use slicing to print the string "race" from my_string. b. Use slicing to print the string "cec" from my_string in reverse order. c. Check if my_string is a palindrome (i.e., reads the same forwards and
# backwards) and print the result.

# %%
my_string="racecar"

# %%
my_string[:4]
# Out:
# 'race'

# %%
my_string[2:5]
# Out:
# 'cec'

# %%
a=my_string

for i in a:
  b=a[::-1]

if b==a:
  print("true its a palindrome")
else:
  print("false its not a palindrome")

print("The Original String is:",a)
print("The String after reverse is",b)
# Out:
# true its a palindrome
# The Original String is: racecar
# The String after reverse is racecar
